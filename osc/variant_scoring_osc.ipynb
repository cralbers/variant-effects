# %% [markdown]
# # OSC variant vcf scoring

# %%
# %%bash
# module load miniconda3/24.1.2-py310
# module load cuda/12.4.1
# conda activate py311

# %%
from alphagenome_research.model import dna_model
from alphagenome import colab_utils
from alphagenome.data import gene_annotation
from alphagenome.data import genome
from alphagenome.data import transcript as transcript_utils
from alphagenome.interpretation import ism
from alphagenome.models import dna_client
from alphagenome.models import variant_scorers
from alphagenome.visualization import plot_components
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
# os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '0.9'
# os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
# os.environ["TF_GPU_ALLOCATOR"]='cuda_malloc_async'

import matplotlib.pyplot as plt
import pandas as pd
import pysam
from pysam import VariantFile
from io import StringIO
from tqdm import tqdm
import os
# from dotenv import load_dotenv

pd.set_option('display.max_columns', None)

# %%
LMNA_START = 156_114_711
LMNA_END = 156_140_081
gene_symbol = "LMNA"
LMNA_INTERVAL = genome.Interval('chr1', 156_114_711, 156_140_081)

BASE_PATH = '/users/PAS2905/coraalbers/'

AG_DATA_PATH = '/users/PAS2905/coraalbers/ag/ag_data/'

HG38_FASTA_PATH = '/users/PAS2905/coraalbers/ag/hg38.fa'
HG38_GTF_PATH = '/users/PAS2905/coraalbers/ag/ag_data/gencode.v46.annotation.gtf.gz.feather'
HG38_SPLICE_START_PATH = '/users/PAS2905/coraalbers/ag/ag_data/gencode.v46.splice_sites_starts.feather'
HG38_SPLICE_END_PATH = '/users/PAS2905/coraalbers/ag/ag_data/gencode.v46.splice_sites_ends.feather'

CLINVAR_PATH = '/users/PAS2905/coraalbers/ag/clinvar.vcf.gz'

HEART_UB = 'UBERON:0000948'
LV_UB = 'UBERON:0002084'

gtf = pd.read_feather(
    HG38_GTF_PATH
)

# %%
# load_dotenv(override=True)
# api_key = os.getenv("AG_API_KEY")

# dna_model = dna_client.create(api_key)
# print(os.getenv('AG_API_KEY'))
model = dna_model.create_from_huggingface( 
    'all_folds', 
    organism_settings={ 
        dna_model.Organism.HOMO_SAPIENS: dna_model.OrganismSettings( 
            fasta_path=HG38_FASTA_PATH, 
            
            gtf_feather_path=HG38_GTF_PATH, 
            splice_site_starts_feather_path=HG38_SPLICE_START_PATH, 
            splice_site_ends_feather_path=HG38_SPLICE_END_PATH, 
        ), dna_model.Organism.MUS_MUSCULUS: dna_model.OrganismSettings() } )

print('all folds model initialized!')
# Out:
# Fetching 12 files: 100%|██████████| 12/12 [00:00<00:00, 6513.74it/s]
# all folds model initialized!

# %%
# # generate clinvar vcf index
# pysam.tabix_index(f"{BASE_PATH}ag/clinvar.vcf.gz", preset="vcf", force=True)

# %%
# Open local or compressed VCF file
vcf_in = VariantFile(f"{BASE_PATH}ag/clinvar.vcf.gz")

# %%
# vcf_in = VariantFile("/Users/coraalbers/Documents/BSGP/Lancaster_rotation/data/clinvar.vcf.gz")

# n = 5
# for i, record in enumerate(vcf_in.fetch()):
#     print(record)
#     print(record.info.keys())
#     print(record.info["CLNSIG"])
#     if i + 1 >= n:
#         break

# %%
# gene_interval = gene_annotation.get_gene_interval(gtf, gene_symbol="LMNA")

# window_bp = 1_000_000

# search_interval = gene_interval.pad(window_bp, window_bp)
# # or manually:
# # search_start = gene_interval.start - window_bp
# # search_end = gene_interval.end + window_bp

# %%
gene_symbol = "LMNA"
window_bp = 1_000_000

gene_interval = gene_annotation.get_gene_interval(gtf, gene_symbol=gene_symbol)
region = gene_interval.pad(window_bp, window_bp)
vcf_contig = region.chromosome.removeprefix("chr")

vcf_path = CLINVAR_PATH
with VariantFile(vcf_path) as vcf_in:
    nearby = [
        rec for rec in vcf_in.fetch(
            vcf_contig,
            max(region.start - 1, 0),
            region.end,
        )
    ]
print(f"{len(nearby)} variants within ±{window_bp:,} bp of {gene_symbol}")
print(f"Region: {region.chromosome}:{region.start}-{region.end}")
# Out:
# 13076 variants within ±1,000,000 bp of LMNA
# Region: chr1:155082571-157140081

# %%
def variants_near_gene(vcf_path, gene_symbol, gtf, window_bp=1_000_000):
    region = gene_interval.pad(window_bp, window_bp)
    contig = to_vcf_contig(region.chromosome)
    gene_interval = gene_annotation.get_gene_interval(gtf, gene_symbol=gene_symbol)
    with VariantFile(vcf_path) as vcf_in:
        # nearby = [
        #     rec for rec in vcf_in.fetch(
        #         vcf_contig,
        #         max(region.start - 1, 0),
        #         region.end,
        #     )
        # ]
        # print(f"{len(nearby)} variants within ±{window_bp:,} bp of {gene_symbol}")
        # print(f"Region: {region.chromosome}:{region.start}-{region.end}")

        for record in vcf_in.fetch(contig, max(region.start - 1, 0), region.end):
            yield record

# %%
variants_near_gene(vcf_path, 'LMNA', gtf, 1_000_000)
# Out:
# <generator object variants_near_gene at 0x148014a442a0>

# %%
def to_vcf_contig(chrom: str) -> str:
    return chrom.removeprefix("chr")  # 'chr1' -> '1'

def variants_near_gene(vcf_in, gene_interval, window_bp=1_000_000):
    region = gene_interval.pad(window_bp, window_bp)
    contig = to_vcf_contig(region.chromosome)
    for record in vcf_in.fetch(contig, max(region.start - 1, 0), region.end):
        yield record

# # write a filtered vcf file with variants near the gene
# with VariantFile(vcf_path) as vcf_in, VariantFile(f"{BASE_PATH}ag/variant-effects/osc/outputs/lmna_within_1Mb.vcf", "w", header=vcf_in.header) as vcf_out:
#     for record in variants_near_gene(vcf_in, gene_interval):
#         vcf_out.write(record)

# %%
PATHOGENIC = {
    "Pathogenic",
    "Likely_pathogenic",
    "Pathogenic/Likely_pathogenic",
    "Uncertain_significance"
    
}

def is_pathogenic(record, gene_filter=False):
    clnsig = record.info.get("CLNSIG")
    if clnsig is None:
        return False
    # pysam returns a tuple for Number=. fields
    if gene_filter:
        if "LMNA:" in record.info.get("GENEINFO", ""):
            if isinstance(clnsig, tuple):
                return any(sig in PATHOGENIC for sig in clnsig)

    else: 
        if isinstance(clnsig, tuple):
            return any(sig in PATHOGENIC for sig in clnsig)
        
    return clnsig in PATHOGENIC

# %%
nearby_vcf = f'{BASE_PATH}ag/variant-effects/osc/outputs/lmna_within_1Mb.vcf'

# with VariantFile(nearby_vcf) as nearby_in, \
#      VariantFile(f'{BASE_PATH}ag/variant-effects/osc/outputs/lmna_variants_pathogenic_VUS_LMNA.vcf', "w", header=nearby_in.header) as vcf_out:
#     count = 0
#     for record in nearby_in.fetch():
#         if is_pathogenic(record, gene_filter=True): 
#             # print(record)
#             vcf_out.write(record)
#             count += 1
# print(f"Wrote {count} pathogenic variants")

# %% [markdown]
# ## convert vcf to csv

# %%
def get_vcf_names(vcf_path):
    """Finds the true column header line inside the VCF file."""
    with open(vcf_path, "r") as f:
        for line in f:
            if line.startswith("#CHROM"):
                # Remove the leading '#' and split by tabs
                return line.strip("#").strip().split("\t")
    raise ValueError("No header line starting with '#CHROM' found.")


vcf_filename = f'{BASE_PATH}ag/variant-effects/osc/outputs/lmna_variants_pathogenic_VUS_notLMNAlabeled.vcf'
csv_filename = f'{BASE_PATH}ag/variant-effects/osc/outputs/lmna_variants_pathogenic_VUS_notLMNAlabeled.csv'

# Fetch headers dynamically
column_names = get_vcf_names(vcf_filename)

# Read the VCF file, skipping metadata rows starting with '##'
df = pd.read_csv(
    vcf_filename,
    comment="#",
    sep="\t",
    names=column_names,
    header=None,
    low_memory=False,
)
df['CHROM'] = 'chr1'
df

# Export the clean structure to a CSV
df.to_csv(csv_filename, index=False)
print(f"Successfully exported genomic VCF data to {csv_filename}!")
# Out:
# Successfully exported genomic VCF data to /users/PAS2905/coraalbers/ag/variant-effects/osc/outputs/lmna_variants_pathogenic_VUS_notLMNAlabeled.csv!

# %% [markdown]
# ## predict variants
# from https://www.alphagenomedocs.com/colabs/batch_variant_scoring.html

# %%
csv_file = f'{BASE_PATH}ag/variant-effects/osc/outputs/lmna_variants_pathogenic_VUS_LMNA.csv'
vcf = pd.read_csv(csv_file, sep=',')
print(vcf.columns)
required_columns = ['ID', 'CHROM', 'POS', 'REF', 'ALT']
for column in required_columns:
  if column not in vcf.columns:
    raise ValueError(f'VCF file is missing required column: {column}.')

organism = 'human'  # @param ["human", "mouse"] {type:"string"}

# @markdown Specify length of sequence around variants to predict:
sequence_length = '500KB'  # @param ["16KB", "100KB", "500KB", "1MB"] { type:"string" }
sequence_length = dna_client.SUPPORTED_SEQUENCE_LENGTHS[
    f'SEQUENCE_LENGTH_{sequence_length}'
]


# @markdown Specify which scorers to use to score your variants:
score_rna_seq = True  # @param { type: "boolean"}
score_cage = True  # @param { type: "boolean" }
score_procap = True  # @param { type: "boolean" }
score_atac = True  # @param { type: "boolean" }
score_dnase = True  # @param { type: "boolean" }
score_chip_histone = True  # @param { type: "boolean" }
score_chip_tf = True  # @param { type: "boolean" }
score_polyadenylation = False  # @param { type: "boolean" }
score_splice_sites = True  # @param { type: "boolean" }
score_splice_site_usage = True  # @param { type: "boolean" }
score_splice_junctions = True  # @param { type: "boolean" }



# Parse organism specification.
organism_map = {
    'human': dna_client.Organism.HOMO_SAPIENS,
    'mouse': dna_client.Organism.MUS_MUSCULUS,
}
organism = organism_map[organism]

# Parse scorer specification.
scorer_selections = {
    'rna_seq': score_rna_seq,
    'cage': score_cage,
    'procap': score_procap,
    'atac': score_atac,
    'dnase': score_dnase,
    'chip_histone': score_chip_histone,
    'chip_tf': score_chip_tf,
    'polyadenylation': score_polyadenylation,
    'splice_sites': score_splice_sites,
    'splice_site_usage': score_splice_site_usage,
    'splice_junctions': score_splice_junctions,
}

all_scorers = variant_scorers.RECOMMENDED_VARIANT_SCORERS
# print(all_scorers)
selected_scorers = [
    all_scorers[key]
    for key in all_scorers
    if scorer_selections.get(key.lower(), False)
]



# Remove any scorers or output types that are not supported for the chosen organism.
unsupported_scorers = [
    scorer
    for scorer in selected_scorers
    if (
        organism.value
        not in variant_scorers.SUPPORTED_ORGANISMS[scorer.base_variant_scorer]
    )
    | (
        (scorer.requested_output == dna_client.OutputType.PROCAP)
        & (organism == dna_client.Organism.MUS_MUSCULUS)
    )
]
if len(unsupported_scorers) > 0:
  print(
      f'Excluding {unsupported_scorers} scorers as they are not supported for'
      f' {organism}.'
  )
  for unsupported_scorer in unsupported_scorers:
    selected_scorers.remove(unsupported_scorer)
# Out:
# Index(['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO'], dtype='object')

# %%
# Score variants in the VCF file.
results = []

for i, vcf_row in tqdm(vcf.iterrows(), total=len(vcf)):
# vcf_row = next(vcf.iterrows())[1]
    variant = genome.Variant(
      chromosome=str(vcf_row.CHROM),
      position=int(vcf_row.POS),
      reference_bases=vcf_row.REF,
      alternate_bases=vcf_row.ALT,
      name=vcf_row.ID,
    )
    interval = variant.reference_interval.resize(sequence_length)
    
    variant_scores = model.score_variant(
      interval=interval,
      variant=variant,
      variant_scorers=selected_scorers,
      organism=organism,
    )
    results.append(variant_scores)

df_scores = variant_scorers.tidy_scores(results)


# @markdown Other settings:
download_predictions = True  # @param { type: "boolean" }

if download_predictions:
  df_scores.to_csv(f'{BASE_PATH}ag/variant-effects/osc/outputs/lmna_variants_pathogenic_VUS_LMNA.{sequence_length}.scores.csv', index=False)
#   files.download('variant_scores.csv')

print('completed')
# Out:
# 100%|██████████| 1426/1426 [44:22<00:00,  1.87s/it]
#                   variant_id             scored_interval          gene_id  \
# 0         chr1:156114693:C>T  chr1:155852549-156376837:.             None
# 1         chr1:156114693:C>T  chr1:155852549-156376837:.             None
# 2         chr1:156114693:C>T  chr1:155852549-156376837:.             None
# 3         chr1:156114693:C>T  chr1:155852549-156376837:.             None
# 4         chr1:156114693:C>T  chr1:155852549-156376837:.             None
# ...                      ...                         ...              ...
# 31030665  chr1:156139828:T>C  chr1:155877684-156401972:.  ENSG00000160789
# 31030666  chr1:156139828:T>C  chr1:155877684-156401972:.  ENSG00000160789
# 31030667  chr1:156139828:T>C  chr1:155877684-156401972:.  ENSG00000160789
# 31030668  chr1:156139828:T>C  chr1:155877684-156401972:.  ENSG00000160789
# 31030669  chr1:156139828:T>C  chr1:155877684-156401972:.  ENSG00000160789
#
#          gene_name       gene_type gene_strand junction_Start junction_End  \
# 0             None            None        None           None         None
# 1             None            None        None           None         None
# 2             None            None        None           None         None
# 3             None            None        None           None         None
# 4             None            None        None           None         None
# ...            ...             ...         ...            ...          ...
# 31030665      LMNA  protein_coding           +      156090582    156130616
# 31030666      LMNA  protein_coding           +      156130773    156139769
# 31030667      LMNA  protein_coding           +      156130773    156135900
# 31030668      LMNA  protein_coding           +      156083849    156114442
# 31030669      LMNA  protein_coding           +      156130773    156136213
#
#                output_type                                     variant_scorer  \
# 0                     ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# 1                     ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# 2                     ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# 3                     ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# 4                     ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# ...                    ...                                                ...
# 31030665  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 31030666  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 31030667  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 31030668  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 31030669  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
#
#                                      track_name track_strand    Assay title  \
# 0                           CL:0000084 ATAC-seq            .       ATAC-seq
# 1                           CL:0000100 ATAC-seq            .       ATAC-seq
# 2                           CL:0000236 ATAC-seq            .       ATAC-seq
# 3                           CL:0000623 ATAC-seq            .       ATAC-seq
# 4                           CL:0000624 ATAC-seq            .       ATAC-seq
# ...                                         ...          ...            ...
# 31030665  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
# 31030666  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
# 31030667  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
# 31030668  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
# 31030669  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
#
#           ontology_curie                   biosample_name  \
# 0             CL:0000084                           T-cell
# 1             CL:0000100                     motor neuron
# 2             CL:0000236                           B cell
# 3             CL:0000623              natural killer cell
# 4             CL:0000624  CD4-positive, alpha-beta T cell
# ...                  ...                              ...
# 31030665  UBERON:0036149                  suprapubic skin
# 31030666  UBERON:0036149                  suprapubic skin
# 31030667  UBERON:0036149                  suprapubic skin
# 31030668  UBERON:0036149                  suprapubic skin
# 31030669  UBERON:0036149                  suprapubic skin
#
#                          biosample_type biosample_life_stage data_source  \
# 0                          primary_cell                adult      encode
# 1         in_vitro_differentiated_cells                adult      encode
# 2                          primary_cell                adult      encode
# 3                          primary_cell                adult      encode
# 4                          primary_cell                adult      encode
# ...                                 ...                  ...         ...
# 31030665                         tissue                adult      encode
# 31030666                         tissue                adult      encode
# 31030667                         tissue                adult      encode
# 31030668                         tissue                adult      encode
# 31030669                         tissue                adult      encode
#
#          endedness genetically_modified transcription_factor histone_mark  \
# 0           paired                False                  NaN          NaN
# 1           paired                False                  NaN          NaN
# 2           paired                False                  NaN          NaN
# 3           paired                False                  NaN          NaN
# 4           paired                False                  NaN          NaN
# ...            ...                  ...                  ...          ...
# 31030665       NaN                  NaN                  NaN          NaN
# 31030666       NaN                  NaN                  NaN          NaN
# 31030667       NaN                  NaN                  NaN          NaN
# 31030668       NaN                  NaN                  NaN          NaN
# 31030669       NaN                  NaN                  NaN          NaN
#
#          gtex_tissue  raw_score
# 0                NaN  -0.185082
# 1                NaN   0.135565
# 2                NaN  -0.195181
# 3                NaN  -0.185215
# 4                NaN  -0.186056
# ...              ...        ...
# 31030665               0.000000
# 31030666               0.000000
# 31030667               0.030579
# 31030668               0.000000
# 31030669               0.019043
#
# [31030670 rows x 24 columns]

# %%
# Examine just the effects of the variants on T-cells.
columns = [c for c in df_scores.columns if c != 'ontology_curie']
df_scores[(df_scores['ontology_curie'] == HEART_UB)][columns]
# Out:
#                variant_id             scored_interval          gene_id  \
# 387    chr1:155085095:C>T  chr1:154822951-155347239:.             None
# 2883   chr1:155085095:C>T  chr1:154822951-155347239:.             None
# 2884   chr1:155085095:C>T  chr1:154822951-155347239:.             None
# 2885   chr1:155085095:C>T  chr1:154822951-155347239:.             None
# 2886   chr1:155085095:C>T  chr1:154822951-155347239:.             None
# ...                   ...                         ...              ...
# 23608  chr1:155085095:C>T  chr1:154822951-155347239:.  ENSG00000143590
# 24339  chr1:155085095:C>T  chr1:154822951-155347239:.  ENSG00000251246
# 24340  chr1:155085095:C>T  chr1:154822951-155347239:.  ENSG00000143590
# 24341  chr1:155085095:C>T  chr1:154822951-155347239:.  ENSG00000251246
# 24342  chr1:155085095:C>T  chr1:154822951-155347239:.  ENSG00000143590
#
#          gene_name       gene_type gene_strand junction_Start junction_End  \
# 387           None            None        None           None         None
# 2883          None            None        None           None         None
# 2884          None            None        None           None         None
# 2885          None            None        None           None         None
# 2886          None            None        None           None         None
# ...            ...             ...         ...            ...          ...
# 23608        EFNA3  protein_coding           +           None         None
# 24339  EFNA4-EFNA3  protein_coding           +      155079069    155085315
# 24340        EFNA3  protein_coding           +      155079069    155085315
# 24341  EFNA4-EFNA3  protein_coding           +      155079069    155085315
# 24342        EFNA3  protein_coding           +      155079069    155085315
#
#              output_type                                     variant_scorer  \
# 387                DNASE  CenterMaskScorer(requested_output=DNASE, width...
# 2883        CHIP_HISTONE  CenterMaskScorer(requested_output=CHIP_HISTONE...
# 2884        CHIP_HISTONE  CenterMaskScorer(requested_output=CHIP_HISTONE...
# 2885        CHIP_HISTONE  CenterMaskScorer(requested_output=CHIP_HISTONE...
# 2886        CHIP_HISTONE  CenterMaskScorer(requested_output=CHIP_HISTONE...
# ...                  ...                                                ...
# 23608  SPLICE_SITE_USAGE  GeneMaskSplicingScorer(requested_output=SPLICE...
# 24339   SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 24340   SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 24341   SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 24342   SPLICE_JUNCTIONS                             SpliceJunctionScorer()
#
#                                        track_name track_strand  \
# 387                      UBERON:0000948 DNase-seq            .
# 2883     UBERON:0000948 Histone ChIP-seq H3K27me3            .
# 2884      UBERON:0000948 Histone ChIP-seq H3K4me1            .
# 2885      UBERON:0000948 Histone ChIP-seq H3K4me3            .
# 2886       UBERON:0000948 Histone ChIP-seq H3K9ac            .
# ...                                           ...          ...
# 23608          usage_UBERON:0000948 total RNA-seq            +
# 24339  junction_UBERON:0000948 polyA plus RNA-seq            .
# 24340  junction_UBERON:0000948 polyA plus RNA-seq            .
# 24341       junction_UBERON:0000948 total RNA-seq            .
# 24342       junction_UBERON:0000948 total RNA-seq            .
#
#               Assay title biosample_name biosample_type biosample_life_stage  \
# 387             DNase-seq          heart         tissue            embryonic
# 2883     Histone ChIP-seq          heart         tissue            embryonic
# 2884     Histone ChIP-seq          heart         tissue            embryonic
# 2885     Histone ChIP-seq          heart         tissue            embryonic
# 2886     Histone ChIP-seq          heart         tissue            embryonic
# ...                   ...            ...            ...                  ...
# 23608       total RNA-seq          heart         tissue                adult
# 24339  polyA plus RNA-seq          heart         tissue                adult
# 24340  polyA plus RNA-seq          heart         tissue                adult
# 24341       total RNA-seq          heart         tissue                adult
# 24342       total RNA-seq          heart         tissue                adult
#
#       data_source endedness genetically_modified transcription_factor  \
# 387        encode    paired                False                  NaN
# 2883       encode    single                False                  NaN
# 2884       encode    single                False                  NaN
# 2885       encode    single                False                  NaN
# 2886       encode    single                False                  NaN
# ...           ...       ...                  ...                  ...
# 23608      encode       NaN                  NaN                  NaN
# 24339      encode       NaN                  NaN                  NaN
# 24340      encode       NaN                  NaN                  NaN
# 24341      encode       NaN                  NaN                  NaN
# 24342      encode       NaN                  NaN                  NaN
#
#       histone_mark gtex_tissue  raw_score
# 387            NaN         NaN   0.008914
# 2883      H3K27me3         NaN   0.011138
# 2884       H3K4me1         NaN  -0.005752
# 2885       H3K4me3         NaN   0.014744
# 2886        H3K9ac         NaN   0.005914
# ...            ...         ...        ...
# 23608          NaN               0.015625
# 24339          NaN               0.151367
# 24340          NaN               0.151367
# 24341          NaN               0.149902
# 24342          NaN               0.149902
#
# [162 rows x 23 columns]

# %%
lmna_var_scores = pd.read_csv(f'{BASE_PATH}ag/variant-effects/osc/outputs/lmna_variants_pathogenic_VUS_LMNA.524288.scores.csv')
lmna_var_scores
# Out:
#                variant_id             scored_interval          gene_id  \
# 0      chr1:156114693:C>T  chr1:155852549-156376837:.              NaN
# 1      chr1:156114693:C>T  chr1:155852549-156376837:.              NaN
# 2      chr1:156114693:C>T  chr1:155852549-156376837:.              NaN
# 3      chr1:156114693:C>T  chr1:155852549-156376837:.              NaN
# 4      chr1:156114693:C>T  chr1:155852549-156376837:.              NaN
# ...                   ...                         ...              ...
# 29702  chr1:156114693:C>T  chr1:155852549-156376837:.  ENSG00000160789
# 29703  chr1:156114693:C>T  chr1:155852549-156376837:.  ENSG00000160789
# 29704  chr1:156114693:C>T  chr1:155852549-156376837:.  ENSG00000160789
# 29705  chr1:156114693:C>T  chr1:155852549-156376837:.  ENSG00000160789
# 29706  chr1:156114693:C>T  chr1:155852549-156376837:.  ENSG00000160789
#
#       gene_name       gene_type gene_strand  junction_Start  junction_End  \
# 0           NaN             NaN         NaN             NaN           NaN
# 1           NaN             NaN         NaN             NaN           NaN
# 2           NaN             NaN         NaN             NaN           NaN
# 3           NaN             NaN         NaN             NaN           NaN
# 4           NaN             NaN         NaN             NaN           NaN
# ...         ...             ...         ...             ...           ...
# 29702      LMNA  protein_coding           +     156134528.0   156135900.0
# 29703      LMNA  protein_coding           +     156137028.0   156139079.0
# 29704      LMNA  protein_coding           +     156137743.0   156139079.0
# 29705      LMNA  protein_coding           +     156130773.0   156137112.0
# 29706      LMNA  protein_coding           +     156137943.0   156138487.0
#
#             output_type                                     variant_scorer  \
# 0                  ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# 1                  ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# 2                  ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# 3                  ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# 4                  ATAC  CenterMaskScorer(requested_output=ATAC, width=...
# ...                 ...                                                ...
# 29702  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 29703  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 29704  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 29705  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
# 29706  SPLICE_JUNCTIONS                             SpliceJunctionScorer()
#
#                                   track_name track_strand    Assay title  \
# 0                        CL:0000084 ATAC-seq            .       ATAC-seq
# 1                        CL:0000100 ATAC-seq            .       ATAC-seq
# 2                        CL:0000236 ATAC-seq            .       ATAC-seq
# 3                        CL:0000623 ATAC-seq            .       ATAC-seq
# 4                        CL:0000624 ATAC-seq            .       ATAC-seq
# ...                                      ...          ...            ...
# 29702  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
# 29703  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
# 29704  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
# 29705  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
# 29706  junction_UBERON:0036149 total RNA-seq            .  total RNA-seq
#
#        ontology_curie                   biosample_name  \
# 0          CL:0000084                           T-cell
# 1          CL:0000100                     motor neuron
# 2          CL:0000236                           B cell
# 3          CL:0000623              natural killer cell
# 4          CL:0000624  CD4-positive, alpha-beta T cell
# ...               ...                              ...
# 29702  UBERON:0036149                  suprapubic skin
# 29703  UBERON:0036149                  suprapubic skin
# 29704  UBERON:0036149                  suprapubic skin
# 29705  UBERON:0036149                  suprapubic skin
# 29706  UBERON:0036149                  suprapubic skin
#
#                       biosample_type biosample_life_stage data_source  \
# 0                       primary_cell                adult      encode
# 1      in_vitro_differentiated_cells                adult      encode
# 2                       primary_cell                adult      encode
# 3                       primary_cell                adult      encode
# 4                       primary_cell                adult      encode
# ...                              ...                  ...         ...
# 29702                         tissue                adult      encode
# 29703                         tissue                adult      encode
# 29704                         tissue                adult      encode
# 29705                         tissue                adult      encode
# 29706                         tissue                adult      encode
#
#       endedness genetically_modified transcription_factor histone_mark  \
# 0        paired                False                  NaN          NaN
# 1        paired                False                  NaN          NaN
# 2        paired                False                  NaN          NaN
# 3        paired                False                  NaN          NaN
# 4        paired                False                  NaN          NaN
# ...         ...                  ...                  ...          ...
# 29702       NaN                  NaN                  NaN          NaN
# 29703       NaN                  NaN                  NaN          NaN
# 29704       NaN                  NaN                  NaN          NaN
# 29705       NaN                  NaN                  NaN          NaN
# 29706       NaN                  NaN                  NaN          NaN
#
#       gtex_tissue  raw_score
# 0             NaN  -0.185082
# 1             NaN   0.135565
# 2             NaN  -0.195181
# 3             NaN  -0.185215
# 4             NaN  -0.186056
# ...           ...        ...
# 29702         NaN   0.354980
# 29703         NaN   0.297119
# 29704         NaN   0.237793
# 29705         NaN   0.205200
# 29706         NaN   0.126343
#
# [29707 rows x 24 columns]

# %%
lmna_var_scores['variant_id'].unique()
# Out:
# array(['chr1:156114693:C>T'], dtype=object)

# %%
# # Score variants in the VCF file.
# results = []

# for i, vcf_row in tqdm(vcf.iterrows(), total=len(vcf)):
#   variant = genome.Variant(
#       chromosome=str(vcf_row.CHROM),
#       position=int(vcf_row.POS),
#       reference_bases=vcf_row.REF,
#       alternate_bases=vcf_row.ALT,
#       name=vcf_row.ID,
#   )
#   interval = variant.reference_interval.resize(sequence_length)

#   variant_scores = model.score_variant(
#       interval=interval,
#       variant=variant,
#       variant_scorers=selected_scorers,
#       organism=organism,
#   )
#   results.append(variant_scores)

# df_scores = variant_scorers.tidy_scores(results)


# # @markdown Other settings:
# download_predictions = True  # @param { type: "boolean" }

# if download_predictions:
#   df_scores.to_csv(f'{BASE_PATH}ag/variant-effects/osc/outputs/lmna_variants_pathogenic_VUS_LMNA.scores.csv', index=False)
# #   files.download('variant_scores.csv')

# df_scores

# %%
# df_scores.to_pickle('lmna_pathogenic_variant_scores.pkl')
# # @markdown Other settings:
# download_predictions = True  # @param { type: "boolean" }

# if download_predictions:
#   df_scores.to_csv('/Users/coraalbers/Documents/BSGP/Lancaster_rotation/data/lmna_variant_scores.csv', index=False)
#   # files.download('/Users/coraalbers/Documents/BSGP/Lancaster_rotation/data/lmna_variant_scores.csv')

# %%
columns = [c for c in df_scores.columns if c != 'ontology_curie']
heart_df_scores = df_scores[(df_scores['ontology_curie'] == 'UBERON:0000948')][columns] # heart uberon identifier
heart_df_scores.to_csv('/Users/coraalbers/Documents/BSGP/Lancaster_rotation/data/lmna_variant_scores_heart_UBERON0000948.csv', index=False)

# %%
heart_df_scores.head()
# Out:
#               variant_id             scored_interval gene_id gene_name  \
# 387   chr1:156114693:C>T  chr1:156049157-156180229:.    None      None
# 2883  chr1:156114693:C>T  chr1:156049157-156180229:.    None      None
# 2884  chr1:156114693:C>T  chr1:156049157-156180229:.    None      None
# 2885  chr1:156114693:C>T  chr1:156049157-156180229:.    None      None
# 2886  chr1:156114693:C>T  chr1:156049157-156180229:.    None      None
#
#      gene_type gene_strand junction_Start junction_End   output_type  \
# 387       None        None           None         None         DNASE
# 2883      None        None           None         None  CHIP_HISTONE
# 2884      None        None           None         None  CHIP_HISTONE
# 2885      None        None           None         None  CHIP_HISTONE
# 2886      None        None           None         None  CHIP_HISTONE
#
#                                          variant_scorer  \
# 387   CenterMaskScorer(requested_output=DNASE, width...
# 2883  CenterMaskScorer(requested_output=CHIP_HISTONE...
# 2884  CenterMaskScorer(requested_output=CHIP_HISTONE...
# 2885  CenterMaskScorer(requested_output=CHIP_HISTONE...
# 2886  CenterMaskScorer(requested_output=CHIP_HISTONE...
#
#                                     track_name track_strand       Assay title  \
# 387                   UBERON:0000948 DNase-seq            .         DNase-seq
# 2883  UBERON:0000948 Histone ChIP-seq H3K27me3            .  Histone ChIP-seq
# 2884   UBERON:0000948 Histone ChIP-seq H3K4me1            .  Histone ChIP-seq
# 2885   UBERON:0000948 Histone ChIP-seq H3K4me3            .  Histone ChIP-seq
# 2886    UBERON:0000948 Histone ChIP-seq H3K9ac            .  Histone ChIP-seq
#
#      biosample_name biosample_type biosample_life_stage data_source endedness  \
# 387           heart         tissue            embryonic      encode    paired
# 2883          heart         tissue            embryonic      encode    single
# 2884          heart         tissue            embryonic      encode    single
# 2885          heart         tissue            embryonic      encode    single
# 2886          heart         tissue            embryonic      encode    single
#
#      genetically_modified transcription_factor histone_mark gtex_tissue  \
# 387                 False                  NaN          NaN         NaN
# 2883                False                  NaN     H3K27me3         NaN
# 2884                False                  NaN      H3K4me1         NaN
# 2885                False                  NaN      H3K4me3         NaN
# 2886                False                  NaN       H3K9ac         NaN
#
#       raw_score  quantile_score
# 387    0.141282        0.963955
# 2883  -0.177345       -0.999621
# 2884  -0.000861       -0.134700
# 2885   0.088124        0.988467
# 2886   0.101405        0.989576
