# %% [markdown]
# gtftools.py -t Homo_sapiens.GRCh38.94.gtf.tss.bed -w 1000  Homo_sapiens.GRCh38.94.gtf
#
# https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_46/gencode.v46.annotation.gtf.gz

# %%
# !gtftools -t gr38.tss.bed -w 0-0 gencode.v46.annotation.gtf

# %%
import gffutils
db = gffutils.create_db('/users/PAS2905/coraalbers/ag/ag_data/gencode.v46.annotation.gtf', '/users/PAS2905/coraalbers/ag/ag_data/gencode.v46.annotation.gtf.db')
